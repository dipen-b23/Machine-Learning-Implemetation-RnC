# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart.csv")
df['Sex']=df['Sex'].map({'M': 1, 'F': 0})
df['ExerciseAngina']=df['ExerciseAngina'].map({'N': 0, 'Y': 1})
df = pd.get_dummies(df, columns=['ST_Slope','ChestPainType','RestingECG'], drop_first=False)

# %%
n_entries = len(df)
shuffled_indices = np.random.permutation(n_entries)
train_size = int(n_entries * 0.8)
train_indices = shuffled_indices[:train_size]
test_indices = shuffled_indices[train_size:]
train_df = df.iloc[train_indices]
test_df = df.iloc[test_indices]

# %%
train_df
# Out:
#      Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 36    65    1        140          306          1     87               1
# 312   41    1        125            0          1    176               0
# 647   37    0        120          215          0    170               0
# 292   53    1        130          182          0    148               0
# 493   51    1        137          339          0    127               1
# ..   ...  ...        ...          ...        ...    ...             ...
# 484   65    1        134            0          0    112               1
# 605   51    0        114          258          1     96               0
# 443   60    1        130          186          1    140               1
# 250   44    1        135          491          0    135               0
# 176   54    1        140          216          0    105               0
#
#      Oldpeak  HeartDisease  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up  \
# 36       1.5             1          False           True        False
# 312      1.6             1          False          False         True
# 647      0.0             0          False          False         True
# 292      0.0             0          False          False         True
# 493      1.7             1          False           True        False
# ..       ...           ...            ...            ...          ...
# 484      1.1             1          False           True        False
# 605      1.0             0          False          False         True
# 443      0.5             1          False           True        False
# 250      0.0             1          False           True        False
# 176      1.5             1          False           True        False
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 36                True              False              False
# 312               True              False              False
# 647              False              False               True
# 292               True              False              False
# 493              False              False               True
# ..                 ...                ...                ...
# 484               True              False              False
# 605               True              False              False
# 443               True              False              False
# 250               True              False              False
# 176               True              False              False
#
#      ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST
# 36              False           False               True          False
# 312             False           False               True          False
# 647             False           False               True          False
# 292             False           False               True          False
# 493             False           False               True          False
# ..                ...             ...                ...            ...
# 484             False           False               True          False
# 605             False            True              False          False
# 443             False           False              False           True
# 250             False           False               True          False
# 176             False           False               True          False
#
# [734 rows x 19 columns]

# %%
def sigmoid(z):
    y_head = 1 / (1+np.exp(-z))
    return y_head

# %%
def Cost(x,y,theta):
    length=len(y)
    h=sigmoid(x@theta)
    cost=-(1/length)*(y.T@np.log(h+1e-5)+(1-y).T@np.log(1-h+1e-5))
    return cost[0][0]

# %%
def gradientDes(x,y,alpha,iteration):
    m,n=x.shape
    theta=np.zeros((n,1))
    prevcosts=[]

    for _ in range(iteration):
        z=x@theta
        h=sigmoid(z)
        gradient = (1/m) * (x.T @ (h - y))
        theta -= alpha * gradient
        cost = Cost(x, y, theta)
        prevcosts.append(cost)
    return theta, prevcosts

# %%
x = train_df.drop(columns='HeartDisease').values
y = train_df['HeartDisease'].values.reshape(-1, 1)
y=y.astype(float)
x=x.astype(float)
xmean=x.mean(axis=0)
xstd=x.std(axis=0)
x = (x - xmean) / xstd
bias = np.ones((x.shape[0], 1))
x_scaled = np.concatenate([bias, x], axis=1)
x=x_scaled

# %%
theta, cost_history = gradientDes(x, y,0.1,5000)

# %%
def predict(x, theta):
    probs = sigmoid(x @ theta)
    return (probs >= 0.5).astype(int)
def TrainingAcc(x,y):
    y_pred = predict(x, theta)
    accuracy = (y_pred == y).mean() * 100
    print(f"Training Accuracy: {accuracy:.2f}%")

# %%
x_test=test_df.drop(columns='HeartDisease').values
y_test=test_df.HeartDisease.values.reshape(-1,1)
y_test=y_test.astype(float)
x_test=x_test.astype(float)
x_test = (x_test - xmean) / xstd
bias = np.ones((x_test.shape[0], 1))
x_test_scaled = np.concatenate([bias, x_test], axis=1)
x_test=x_test_scaled

# %%
TrainingAcc(x_test,y_test)
# Out:
# Training Accuracy: 85.33%

# %%
plt.plot(cost_history)
plt.title("Cost Function vs. Epochs")
plt.xlabel("Epochs")
plt.ylabel("Cost")
plt.grid(True)
plt.show()
